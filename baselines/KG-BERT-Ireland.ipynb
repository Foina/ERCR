# %%
# !git clone https://github.com/yao8839836/kg-bert.git
# %cd kg-bert

# !pip install transformers==2.5.1
# !pip install -r requirements.txt
# Out:
# Collecting transformers==2.5.1
#   Downloading transformers-2.5.1-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (2.0.2)
# Collecting tokenizers==0.5.2 (from transformers==2.5.1)
#   Downloading tokenizers-0.5.2.tar.gz (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.6/64.6 kB 5.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting boto3 (from transformers==2.5.1)
#   Downloading boto3-1.40.27-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (3.19.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (2.32.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (4.67.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (2024.11.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from transformers==2.5.1) (0.2.1)
# Collecting sacremoses (from transformers==2.5.1)
#   Downloading sacremoses-0.1.1-py3-none-any.whl.metadata (8.3 kB)
# Collecting botocore<1.41.0,>=1.40.27 (from boto3->transformers==2.5.1)
#   Downloading botocore-1.40.27-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->transformers==2.5.1)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3->transformers==2.5.1)
#   Downloading s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==2.5.1) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==2.5.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==2.5.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==2.5.1) (2025.8.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from sacremoses->transformers==2.5.1) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from sacremoses->transformers==2.5.1) (1.5.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.27->boto3->transformers==2.5.1) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.27->boto3->transformers==2.5.1) (1.17.0)
# Downloading transformers-2.5.1-py3-none-any.whl (499 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.4/499.4 kB 23.9 MB/s eta 0:00:00
# Downloading boto3-1.40.27-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 11.9 MB/s eta 0:00:00
# Downloading sacremoses-0.1.1-py3-none-any.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 43.7 MB/s eta 0:00:00
# Downloading botocore-1.40.27-py3-none-any.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 102.2 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 8.3 MB/s eta 0:00:00
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tokenizers)
# Requirement already satisfied: torch>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.8.0+cu126)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.67.1)
# Collecting boto3 (from -r requirements.txt (line 6))
#   Using cached boto3-1.40.27-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.32.4)
# Collecting pytorch-pretrained-bert>=0.6.2 (from -r requirements.txt (line 10))
#   Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl.metadata (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 3.2 MB/s eta 0:00:00
# Collecting wikipedia (from -r requirements.txt (line 12))
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=0.4.1->-r requirements.txt (line 2)) (3.4.0)
# Collecting botocore<1.41.0,>=1.40.27 (from boto3->-r requirements.txt (line 6))
#   Using cached botocore-1.40.27-py3-none-any.whl.metadata (5.7 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->-r requirements.txt (line 6))
#   Using cached jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3->-r requirements.txt (line 6))
#   Using cached s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->-r requirements.txt (line 8)) (2025.8.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pytorch-pretrained-bert>=0.6.2->-r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from pytorch-pretrained-bert>=0.6.2->-r requirements.txt (line 10)) (2024.11.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from wikipedia->-r requirements.txt (line 12)) (4.13.5)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.41.0,>=1.40.27->boto3->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=0.4.1->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->wikipedia->-r requirements.txt (line 12)) (2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=0.4.1->-r requirements.txt (line 2)) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.27->boto3->-r requirements.txt (line 6)) (1.17.0)
# Using cached boto3-1.40.27-py3-none-any.whl (139 kB)
# Downloading pytorch_pretrained_bert-0.6.2-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 kB 7.1 MB/s eta 0:00:00
# Using cached botocore-1.40.27-py3-none-any.whl (14.0 MB)
# Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Using cached s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (setup.py) ... done
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11678 sha256=7a9eab11f3d2b4f89dc852f4d10a3bb0982ecf6cbd82213f3ed52d69a74f34d8
#   Stored in directory: /root/.cache/pip/wheels/63/47/7c/a9688349aa74d228ce0a9023229c6c0ac52ca2a40fe87679b8
# Successfully built wikipedia
# Installing collected packages: jmespath, wikipedia, botocore, s3transfer, boto3, pytorch-pretrained-bert
# Successfully installed boto3-1.40.27 botocore-1.40.27 jmespath-1.0.1 pytorch-pretrained-bert-0.6.2 s3transfer-0.14.0 wikipedia-1.4.0

# %%
import pandas as pd
import numpy as np
import torch
from transformers import BertTokenizer, BertModel
from tqdm import tqdm
import torch.nn.functional as F
from math import log

# %%
df = pd.read_csv('./data/Irish_populated_places.csv')

# %%
df.head()
# Out:
#                                           place         placeName  \
# 0  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
# 1  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
# 2  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
# 3  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
# 4  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
#
#                                             abstract  \
# 0  Holywell (Irish: Tobar Naofa) is a neighbourho...
# 1  Holywell (Irish: Tobar Naofa) is a neighbourho...
# 2  Holywell (Irish: Tobar Naofa) is a neighbourho...
# 3  Holywell (Irish: Tobar Naofa) is a neighbourho...
# 4  Holywell (Irish: Tobar Naofa) is a neighbourho...
#
#                                            country  \
# 0  http://dbpedia.org/resource/Republic_of_Ireland
# 1  http://dbpedia.org/resource/Republic_of_Ireland
# 2  http://dbpedia.org/resource/Republic_of_Ireland
# 3  http://dbpedia.org/resource/Republic_of_Ireland
# 4  http://dbpedia.org/resource/Republic_of_Ireland
#
#                                              subject  \
# 0  http://dbpedia.org/resource/Category:Neighbour...
# 1  http://dbpedia.org/resource/Category:Neighbour...
# 2  http://dbpedia.org/resource/Category:Neighbour...
# 3  http://dbpedia.org/resource/Category:Neighbour...
# 4  http://dbpedia.org/resource/Category:Neighbour...
#
#                                       broaderSubject  \
# 0  http://dbpedia.org/resource/Category:Swords,_D...
# 1  http://dbpedia.org/resource/Category:Swords,_D...
# 2  http://dbpedia.org/resource/Category:Swords,_D...
# 3  http://dbpedia.org/resource/Category:Swords,_D...
# 4  http://dbpedia.org/resource/Category:Swords,_D...
#
#                                     placeType  \
# 0  http://dbpedia.org/resource/Swords,_Dublin
# 1  http://dbpedia.org/resource/Swords,_Dublin
# 2  http://dbpedia.org/resource/Swords,_Dublin
# 3  http://dbpedia.org/resource/Swords,_Dublin
# 4  http://dbpedia.org/resource/Swords,_Dublin
#
#                              broaderPlaceType  population
# 0           http://dbpedia.org/ontology/Place        2479
# 1        http://dbpedia.org/ontology/Location        2479
# 2  http://dbpedia.org/ontology/PopulatedPlace        2479
# 3      http://dbpedia.org/ontology/Settlement        2479
# 4            http://dbpedia.org/ontology/Town        2479

# %%
with open("data/Irish-Places/entities.txt","w", encoding="utf-8") as f:
  for entity_id in df['place']:
    f.write(f"{entity_id}\n")

# %%
def uri_remove(uri):
  return str(uri).strip().replace("http://dbpedia.org/resource/", "").replace("http://dbpedia.org/ontology/","").replace("Category:","").replace("_", " ")

entity2text, entity2textlong = {}, {}
for idx, row in df.iterrows():
  entity_id = row['place']
  if entity_id not in entity2text:
    text = f"{row['placeName']}. "
    longtext = f"{row['abstract']} "
    longtext += f"Population: {row['population']}"
    entity2text[entity_id] = text
    entity2textlong[entity_id] = longtext


for c in df["country"].unique():
    if c not in entity2text:
      entity2text[c] = f"{uri_remove(c)}"
    if c not in entity2textlong:
      entity2textlong[c] = f"{uri_remove(c)}. A country."


for s in df["subject"].unique():
    if s not in entity2text:
        entity2text[s] = f"{uri_remove(s)}"
    if s not in entity2textlong:
        entity2textlong[s] = f"{uri_remove(s)}. A subject category."

# 3. Add subjects
for s in df["broaderSubject"].unique():
    if s not in entity2text:
        entity2text[s] = f"{uri_remove(s)}"
    if s not in entity2textlong:
        entity2textlong[s] = f"{uri_remove(s)}. A parent subject category."

# 4. Add city types
for t in df["placeType"].unique():
    if t not in entity2text:
        entity2text[t] = f"{uri_remove(t)}"
    if t not in entity2textlong:
        entity2textlong[t] = f"{uri_remove(t)}. A type of place."

# 5. Add broader place types
for bt in df["broaderPlaceType"].unique():
    if bt not in entity2text:
        entity2text[bt] = f"{uri_remove(bt)}"
    if bt not in entity2textlong:
        entity2textlong[bt] = f"{uri_remove(bt)}. A type of place."


with open("data/Irish-Places/entity2text.txt","w", encoding="utf-8") as f:
  for entity, text in entity2text.items():
    f.write(f"{entity}\t{text}\n")

with open("data/Irish-Places/entity2textlong.txt","w", encoding="utf-8") as f:
  for entity, textlong in entity2textlong.items():
    f.write(f"{entity}\t{textlong}\n")

# %%
triples = pd.read_csv("data/triples.tsv", sep="\t", names=['head','relation','tail'])
unstructured_relations = {'dbo:abstract', 'dbo:populationTotal', 'rdfs:label'}
triples = triples[~triples['relation'].isin(unstructured_relations)]

# %%
relations_dict = {"dbo:abstract":"abstract",
                  "dbo:country":"country",
                  "rdfs:label":"the name of the place",
                  "dbo:populationTotal":"population",
                  "dbo:type":"the type of the place",
                  "rdf:type":"an instance of a class",
                  "dcterms:subject":"category of the place",
                  "skos:broader":"parent category"
                  }

# %%
with open("data/Irish-Places/relation2text.txt", "w", encoding="utf-8") as f:
    for r, desc in relations_dict.items():
        f.write(f"{r}\t{desc}\n")

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(triples, test_size=0.2, random_state=42)
valid_df, test_df = train_test_split(test_df, test_size=0.5, random_state=42)

# %%
train_df.to_csv("data/Irish-Places/train.tsv",sep="\t", index=False, header=False)
test_df.to_csv("data/Irish-Places/test.tsv",sep="\t", index=False, header=False)
valid_df.to_csv("data/Irish-Places/dev.tsv",sep="\t", index=False, header=False)

# %%
# !python run_bert_triple_classifier.py --task_name kg --do_train  --do_eval --do_predict --data_dir ./data/Irish-Places --bert_model bert-base-uncased --max_seq_length 20 --train_batch_size 32 \
--learning_rate 5e-5 --num_train_epochs 3.0 --output_dir ./output_Irish-Places-data/  --gradient_accumulation_steps 1 --eval_batch_size 512

# %%
df = pd.read_csv("data/Irish_populated_places.csv")

# %%
df.head(1)
# Out:
#                                           place         placeName  \
# 0  http://dbpedia.org/resource/Holywell,_Swords  Holywell, Swords
#
#                                             abstract  \
# 0  Holywell (Irish: Tobar Naofa) is a neighbourho...
#
#                                            country  \
# 0  http://dbpedia.org/resource/Republic_of_Ireland
#
#                                              subject  \
# 0  http://dbpedia.org/resource/Category:Neighbour...
#
#                                       broaderSubject  \
# 0  http://dbpedia.org/resource/Category:Swords,_D...
#
#                                     placeType  \
# 0  http://dbpedia.org/resource/Swords,_Dublin
#
#                     broaderPlaceType  population
# 0  http://dbpedia.org/ontology/Place        2479

# %%
df['subject'] = df['subject'].str.replace(
    'http://dbpedia.org/resource/Category:', '', regex=False
).map(lambda x: x.replace('_',' '))

# %%
df['broaderSubject'] = df['broaderSubject'].fillna('').str.replace(
    'http://dbpedia.org/resource/Category:', '', regex=False
).str.replace('_', ' ')

# %%
df['country'] = df['country'].fillna('').str.replace(
    'http://dbpedia.org/resource/', '', regex=False
).str.replace('_', ' ')

# %%
df['placeType'] = df['placeType'].fillna('').str.replace(
    'http://dbpedia.org/resource/', '', regex=False
).str.replace('_', ' ')

# %%
df['broaderPlaceType'] = df['broaderPlaceType'].fillna('').str.replace(
    'http://dbpedia.org/ontology/', '', regex=False
)

# %%
agg_df = df.groupby("place", as_index=False).agg({
    "placeName": "first",
    "abstract": "first",
    "country": "first",
    "subject": lambda x: "; ".join(set(x.dropna().astype(str))),
    "broaderSubject": lambda x: "; ".join(set(x.dropna().astype(str))),
    "placeType": lambda x: "; ".join(set(x.dropna().astype(str))),
    "broaderPlaceType": lambda x: "; ".join(set(x.dropna().astype(str))),
    "population": "first"
})

# %%
agg_df.head(10)
# Out:
#                                        place      placeName  \
# 0      http://dbpedia.org/resource/Abbeyleix      Abbeyleix
# 1  http://dbpedia.org/resource/Achill_Island  Achill Island
# 2      http://dbpedia.org/resource/Achillbeg      Achillbeg
# 3       http://dbpedia.org/resource/Aghamore       Aghamore
# 4         http://dbpedia.org/resource/Aglish         Aglish
# 5      http://dbpedia.org/resource/Annacotty      Annacotty
# 6        http://dbpedia.org/resource/Annagry        Annagry
# 7    http://dbpedia.org/resource/Ardnacrusha    Ardnacrusha
# 8      http://dbpedia.org/resource/Ardoileán      Ardoileán
# 9      http://dbpedia.org/resource/Arranmore      Arranmore
#
#                                             abstract              country  \
# 0  Abbeyleix (/ˈæbiːˈliːks/; Irish: Mainistir Lao...  Republic of Ireland
# 1  Achill Island (/ˈækəl/; Irish: Acaill, Oileán ...  Republic of Ireland
# 2  Acaill Bheag (Achillbeg) is a small island in ...  Republic of Ireland
# 3  Aghamore (Irish: Achadh Mór, meaning 'the grea...  Republic of Ireland
# 4  Aglish (Irish: An Eaglais, meaning 'the church...  Republic of Ireland
# 5  Annacotty (Irish: Áth an Choite, meaning 'the ...  Republic of Ireland
# 6  Anagaire (anglicised as Annagry) is a village ...  Republic of Ireland
# 7  Ardnacrusha (Irish: Ard na Croise) is a villag...  Republic of Ireland
# 8  Ardoileán or Ard Oileán, known in English as H...  Republic of Ireland
# 9  Árainn Mhór (English name: Arranmore) is an is...  Republic of Ireland
#
#                                              subject  \
# 0  Towns and villages in County Laois; Planned co...
# 1  Gaeltacht places in County Mayo; Achill Island...
# 2  Villages in Achill Island; Achill Island; Isla...
# 3               Towns and villages in County Leitrim
# 4             Towns and villages in County Waterford
# 5  Limerick (city); Towns and villages in County ...
# 6  Gaeltacht places in County Donegal; The Rosses...
# 7  Populated places on the River Shannon; Towns a...
# 8  Archaeological sites in County Galway; Islands...
# 9  Gaeltacht places in County Donegal; The Rosses...
#
#                                       broaderSubject placeType  \
# 0  Townlands of the Republic of Ireland by county...
# 1  Geography of County Mayo; Islands of County Ma...
# 2  Achill Island; Islands of County Mayo; Ghost t...
# 3  Geography of County Leitrim; Towns and village...
# 4  Geography of County Waterford; Towns and villa...
# 5  Towns and villages in the Republic of Ireland ...
# 6  Wikipedia categories named after districts of ...
# 7  Towns and villages in the Republic of Ireland ...
# 8  Islands of Ireland; Uninhabited islands by cou...
# 9  Wikipedia categories named after districts of ...
#
#   broaderPlaceType  population
# 0                         1770
# 1                         2569
# 2                            1
# 3                          620
# 4                          333
# 5                         2930
# 6                          236
# 7                         1414
# 8                            0
# 9                          469

# %%
def entity_to_text(row):
    text = f"{row['placeName']}. {row['abstract']}. Country: {row['country']}. "
    text += f"category of the place: {row['subject']}. "
    text += f"parent category: {row['broaderSubject']}. "
    text += f"Place types: {row['placeType']}. "
    text += f"Broader place types: {row['broaderPlaceType']}. "
    text += f"Population: {row['population']}"
    return text

agg_df['entity_text'] = agg_df.apply(entity_to_text, axis=1)

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
model = BertModel.from_pretrained("output_Irish-Places-test")
model.eval()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)


entity_repr = {}

for idx, row in tqdm(agg_df.iterrows(), total=len(agg_df), desc="Encoding entities"):
    text = row['entity_text']
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=512)
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model(**inputs)
        cls_embedding = outputs.last_hidden_state[:, 0, :].squeeze()
        entity_repr[row['place']] = cls_embedding.cpu()
# Out:
# Encoding entities: 100%|██████████| 296/296 [04:59<00:00,  1.01s/it]

# %%
def compute_similar_places(entity_repr, top_k=10):
    entities = list(entity_repr.keys())
    all_embeddings = torch.stack([entity_repr[e] for e in entities])  # [N, D]
    sims = F.cosine_similarity(all_embeddings.unsqueeze(1), all_embeddings.unsqueeze(0), dim=-1)

    similar_places_dict = {}
    for i, e in enumerate(entities):
        sim_scores = sims[i]
        topk = torch.topk(sim_scores, k=top_k+1)  # +1 to skip itself
        indices = topk.indices.tolist()
        similar_entities = [entities[j] for j in indices if j != i][:top_k]
        similar_places_dict[e] = similar_entities
    return similar_places_dict

# %%
similar_places = compute_similar_places(entity_repr, top_k=10)

# %%
ground_truth = pd.read_csv("./data/ground_truth.csv")
ground_truth = (
    ground_truth
    .sort_values(
        by=["geographical_entity_1", "F-score"],
        ascending=[True, False]
    )
    .groupby("geographical_entity_1")
    .head(20)
)
y_true_dict = ground_truth.groupby('geographical_entity_1')['geographical_entity_2'].apply(list).to_dict()

# %%
y_true_list = [
    (e1, e2, score)
    for e1, e2, score in ground_truth[['geographical_entity_1', 'geographical_entity_2', 'F-score']].values
]

# %%
def evluation(k, y_true_dict, similar_places_dict):
  invalid_places = []
  # Compute metrics
  precisions, recalls, ndcgs, hits, map_scores,mrrs = [], [], [], [], [], []
  place_idxs = list(y_true_dict.keys())

  for pid in place_idxs:
      if pid not in similar_places_dict or len(similar_places_dict[pid]) < k:
          invalid_places.append(pid)
          continue
      pred_list, rel_set = similar_places_dict[pid][:k], y_true_dict[pid]
      pred_real = "pid:"+str(pid)+' '+"pred_list:"+str(pred_list)+' '+"rel_set:"+str(rel_set)

      if len(pred_list) == 0:
          continue


      dcg = 0.0
      hit_num = 0.0
      for i in range(len(pred_list)):
          if pred_list[i] in rel_set:
              dcg += 1. / (log(i + 2) / log(2))
              hit_num += 1
      # idcg
      idcg = 0.0
      for i in range(min(len(rel_set), len(pred_list))):
          idcg += 1. / (log(i + 2) / log(2))
      ndcg = dcg / idcg
      recall = hit_num / len(rel_set)
      precision = hit_num / len(pred_list)
      hit = 1.0 if hit_num > 0.0 else 0.0

      #map
      map_score = 0.0
      num_hits = 0.0
      score = 0.0
      for i,p in enumerate(pred_list):
          if p in rel_set and p not in pred_list[:i]:
              num_hits+=1.0
              score+=num_hits/(i+1.0)
      map_score = score/min(len(rel_set),k)
      #map_score = score / min(len(rel_set), len(pred_list)) if len(rel_set) > 0 else 0.0

      #MRR
      rr = 0.0
      for i, p in enumerate(pred_list):
        if p in rel_set:
          rr = 1.0 / (i + 1.0)
          break

      ndcgs.append(ndcg)
      recalls.append(recall)
      precisions.append(precision)
      hits.append(hit)
      map_scores.append(map_score)
      mrrs.append(rr)

  avg_precision = np.mean(precisions) * 100
  avg_recall = np.mean(recalls) * 100
  avg_ndcg = np.mean(ndcgs) * 100
  avg_hit = np.mean(hits) * 100
  avg_map = np.mean(map_scores) * 100
  avg_mrr = np.mean(mrrs) * 100

  print("invalid places:", str(len(invalid_places)))
  print('MAP={:.3f} | NDCG={:.3f} |  Recall={:.3f} | Precision={:.3f} | Hits={:.3f} | MRR={:.3f}'.format(
          avg_map, avg_ndcg, avg_recall, avg_precision, avg_hit, avg_mrr))

# %%
evluation(k=10, y_true_dict=y_true_dict, similar_places_dict=similar_places)
# Out:
# invalid places: 0
# MAP=9.818 | NDCG=19.890 |  Recall=8.837 | Precision=17.270 | Hits=78.840 | MRR=43.614
